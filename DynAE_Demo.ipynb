# %% [markdown]
# <a href="https://colab.research.google.com/github/tiwarylab/DynamicsAE/blob/main/DynAE_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DynAE Demo 2023
# This notebook aims to serve as a simple introduction to the dynamics constrained auto-encoder (Dynamics-AE) method ([https://arxiv.org/abs/2209.00905](https://arxiv.org/abs/2209.00905)). The code is implemented using Pytorch.

# %% [markdown]
# ## Clone the Github to Colab

# %%
# !git clone https://github.com/tiwarylab/DynamicsAE
# Out:
# Cloning into 'DynamicsAE'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 28 (delta 6), reused 24 (delta 6), pack-reused 0
# Unpacking objects: 100% (28/28), 5.09 MiB | 5.08 MiB/s, done.

# %%
# %cd DynamicsAE
# %pwd
# Out:
# /content/DynamicsAE
# '/content/DynamicsAE'

# %%
# %matplotlib notebook
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import time

plt.rcParams['figure.figsize'] = [25, 20]
np.random.seed(42)

# %%
large = 54; med = 36; small = 24
l_width = 3; m_width = 1.5; s_width = 0.7
params = {'axes.titlesize': large,
          'legend.fontsize': large,
          'legend.title_fontsize':large,
          'figure.figsize': (16, 10),
          'axes.labelsize': large,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large,
          'lines.linewidth': l_width,
          'lines.markersize': 10,
          'axes.linewidth': l_width,
          'xtick.major.size': 8,
          'ytick.major.size': 8,
          'xtick.minor.size': 4,
          'ytick.minor.size': 4,
          'xtick.major.width': m_width,
          'ytick.major.width': m_width,
          'xtick.minor.width': s_width,
          'ytick.minor.width': s_width,
          'grid.linewidth': m_width}
plt.rcParams.update(params)

# %% [markdown]
# ## Data Preparation
# The trajectory data can be generated from the molecular dynamics simulation or experiements. Here, we use a sample trajectory generated from Langevin dynamics simulation of a three-well analytical potential.

# %%
# Load trajectory data
traj_data = np.load("examples/three_state_traj_data200k.npy")

# %% [markdown]
# ### Visualization of the trajectory

# %%
fig, ax = plt.subplots(figsize=(12,10))

t = np.arange(traj_data.shape[0])*0.01
ax.plot(t[::50],traj_data[::50,0],'x',label='x')
ax.plot(t[::50],traj_data[::50,1],'o',fillstyle='none',label='y')
ax.set_xlabel('time')
ax.legend(fontsize=36,bbox_to_anchor=(0.99, 0.7))

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig,ax = plt.subplots(figsize=(8,7))

RC_counts,RC_xbins,RC_ybins,images = plt.hist2d(traj_data[:,0],traj_data[:,1],bins=100)
RC_counts[RC_counts==0]=RC_counts[RC_counts!=0].min()
RC_G=-np.log(RC_counts)
RC_G=RC_G-np.nanmin(RC_G)

h0=plt.contourf(RC_G.transpose(),levels=10,extent=[RC_xbins[0],RC_xbins[-1],RC_ybins[0],RC_ybins[-1]],cmap='jet')
divider = make_axes_locatable(ax)
cax = divider.append_axes("top", "5%", pad="3%")
tickz = np.arange(0,RC_G.max(),5)
cb1 = fig.colorbar(h0, cax=cax, orientation="horizontal",ticks=tickz)
cb1.set_label(r'Free Energy ($k_BT$)',fontsize=48)
cax.xaxis.set_ticks_position("top")
cax.xaxis.set_label_position("top")
ax.set_xlabel(r"x")
ax.set_ylabel(r"y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Warping the data with a nonlinear mapping function

# %%
# coordinate transformation
traj_data_transformed = traj_data[:,:2].copy()

traj_data_transformed[:,1] = traj_data_transformed[:,1] + traj_data_transformed[:,0]**2

np.save('examples/three_state_transformed_traj_data200k.npy',traj_data_transformed)

# %%
# visualize the transformed trajectory data
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig,ax = plt.subplots(figsize=(8,7))

RC_counts,RC_xbins,RC_ybins,images = plt.hist2d(traj_data_transformed[:,0],traj_data_transformed[:,1],bins=100)
RC_counts[RC_counts==0]=RC_counts[RC_counts!=0].min()
RC_G=-np.log(RC_counts)
RC_G=RC_G-np.nanmin(RC_G)

h0=plt.contourf(RC_G.transpose(),levels=10,extent=[RC_xbins[0],RC_xbins[-1],RC_ybins[0],RC_ybins[-1]],cmap='jet')
divider = make_axes_locatable(ax)
cax = divider.append_axes("top", "5%", pad="3%")
tickz = np.arange(0,RC_G.max(),5)
cb1 = fig.colorbar(h0, cax=cax, orientation="horizontal",ticks=tickz)
cb1.set_label(r'Free Energy ($k_BT$)',fontsize=48)
cax.xaxis.set_ticks_position("top")
cax.xaxis.set_label_position("top")
ax.set_xlabel(r"x'")
ax.set_ylabel(r"y'")
# Out:
# Text(0, 0.5, "y'")

# %% [markdown]
# ## 1. Run Dynamics-AE Model using the given script
# We provide a simple script to run Dynamics-AE using main.py. Here, a configuration file in INI format is supported, which allows a flexible control of the hyper-parameters. A sample configuration file is shown in the `examples` subdirectory.

# %% [markdown]
# ## Training

# %%
# %run main.py -config examples/sample_config.ini
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:546: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# Iteration 500:	Time 4.596982 s
# Loss (train) 0.924663	Regularization loss (train): 3.035448
# Reconstruction loss (train) 0.621118	 Prior loss (train) -2.410913
# Loss (test) 30.871391	Regularization loss (test): 3.017093
# Reconstruction loss (test) 0.700464	 Prior loss (test) -2.197580
# Epoch: 1
#
# Finished after 0.27127623558044434s
# 4 cluster centers detected
#
# Iteration 1000:	Time 10.084112 s
# Loss (train) 2.538173	Regularization loss (train): 0.248462
# Reconstruction loss (train) 0.053549	 Prior loss (train) 0.716405
# Loss (test) 2.150740	Regularization loss (test): 0.186644
# Reconstruction loss (test) 0.284296	 Prior loss (test) 0.872639
# Epoch: 2
#
# Finished after 0.437389612197876s
# 17 cluster centers detected
#
# Iteration 1500:	Time 15.097205 s
# Loss (train) 2.062148	Regularization loss (train): 0.203930
# Reconstruction loss (train) 0.022853	 Prior loss (train) 0.988216
# Loss (test) 1.140014	Regularization loss (test): 0.109132
# Reconstruction loss (test) 0.048690	 Prior loss (test) 0.888287
# Epoch: 3
#
# Finished after 0.432384729385376s
# 22 cluster centers detected
#
# Iteration 2000:	Time 19.948811 s
# Loss (train) 0.641135	Regularization loss (train): 0.063725
# Reconstruction loss (train) 0.003882	 Prior loss (train) 0.803099
# Loss (test) 0.859220	Regularization loss (test): 0.084492
# Reconstruction loss (test) 0.014296	 Prior loss (test) 0.672701
# Epoch: 4
#
# Finished after 0.4663209915161133s
# 23 cluster centers detected
#
# Iteration 2500:	Time 25.571622 s
# Loss (train) 0.521576	Regularization loss (train): 0.049403
# Reconstruction loss (train) 0.027549	 Prior loss (train) 0.844679
# Loss (test) 1.863792	Regularization loss (test): 0.179296
# Reconstruction loss (test) 0.070837	 Prior loss (test) 0.941941
# Epoch: 5
#
# Finished after 0.49863171577453613s
# 26 cluster centers detected
#
# Iteration 3000:	Time 30.543957 s
# Loss (train) 1.198112	Regularization loss (train): 0.110711
# Reconstruction loss (train) 0.091000	 Prior loss (train) 0.794185
# Loss (test) 0.770216	Regularization loss (test): 0.072420
# Reconstruction loss (test) 0.046016	 Prior loss (test) 0.940162
# Epoch: 6
#
# Finished after 0.6419641971588135s
# 23 cluster centers detected
#
# Iteration 3500:	Time 36.326327 s
# Loss (train) 0.864593	Regularization loss (train): 0.085890
# Reconstruction loss (train) 0.005697	 Prior loss (train) 1.146851
# Loss (test) 1.762721	Regularization loss (test): 0.173348
# Reconstruction loss (test) 0.029243	 Prior loss (test) 0.899058
# Epoch: 7
#
# Finished after 0.5177838802337646s
# 27 cluster centers detected
#
# Iteration 4000:	Time 41.300488 s
# Loss (train) 1.556768	Regularization loss (train): 0.153324
# Reconstruction loss (train) 0.023532	 Prior loss (train) 0.929097
# Loss (test) 0.537959	Regularization loss (test): 0.051640
# Reconstruction loss (test) 0.021558	 Prior loss (test) 0.969680
# Epoch: 8
#
# Finished after 0.7743375301361084s
# 28 cluster centers detected
#
# Iteration 4500:	Time 46.857922 s
# Loss (train) 1.363204	Regularization loss (train): 0.134264
# Reconstruction loss (train) 0.020567	 Prior loss (train) 0.665033
# Loss (test) 1.187498	Regularization loss (test): 0.118274
# Reconstruction loss (test) 0.004763	 Prior loss (test) 1.015021
# Epoch: 9
#
# Finished after 0.5219640731811523s
# 31 cluster centers detected
#
# Iteration 5000:	Time 52.082630 s
# Loss (train) 0.421336	Regularization loss (train): 0.041219
# Reconstruction loss (train) 0.009143	 Prior loss (train) 0.957389
# Loss (test) 0.859486	Regularization loss (test): 0.085073
# Reconstruction loss (test) 0.008757	 Prior loss (test) 1.017658
# Epoch: 10
#
# Finished after 0.5029840469360352s
# 29 cluster centers detected
#
# Iteration 5500:	Time 57.074963 s
# Loss (train) 0.528492	Regularization loss (train): 0.050560
# Reconstruction loss (train) 0.022890	 Prior loss (train) 0.930381
# Loss (test) 0.419792	Regularization loss (test): 0.039055
# Reconstruction loss (test) 0.029240	 Prior loss (test) 0.871211
# Iteration 6000:	Time 62.250755 s
# Loss (train) 1.049875	Regularization loss (train): 0.102782
# Reconstruction loss (train) 0.022050	 Prior loss (train) 0.901211
# Loss (test) 0.519778	Regularization loss (test): 0.051148
# Reconstruction loss (test) 0.008302	 Prior loss (test) 0.941443
# Epoch: 11
#
# Finished after 0.48845791816711426s
# 28 cluster centers detected
#
# Iteration 6500:	Time 67.141900 s
# Loss (train) 0.708255	Regularization loss (train): 0.069429
# Reconstruction loss (train) 0.013966	 Prior loss (train) 1.009144
# Loss (test) 1.542308	Regularization loss (test): 0.144365
# Reconstruction loss (test) 0.098662	 Prior loss (test) 0.943955
# Epoch: 12
#
# Finished after 0.5171842575073242s
# 31 cluster centers detected
#
# Iteration 7000:	Time 72.878842 s
# Loss (train) 0.352047	Regularization loss (train): 0.034928
# Reconstruction loss (train) 0.002765	 Prior loss (train) 1.149165
# Loss (test) 0.503547	Regularization loss (test): 0.050200
# Reconstruction loss (test) 0.001545	 Prior loss (test) 0.995457
# Epoch: 13
#
# Finished after 0.5126614570617676s
# 31 cluster centers detected
#
# Iteration 7500:	Time 77.806737 s
# Loss (train) 0.705722	Regularization loss (train): 0.069777
# Reconstruction loss (train) 0.007950	 Prior loss (train) 0.849188
# Loss (test) 0.316663	Regularization loss (test): 0.029974
# Reconstruction loss (test) 0.016919	 Prior loss (test) 0.968323
# Epoch: 14
#
# Finished after 0.49700379371643066s
# 28 cluster centers detected
#
# Iteration 8000:	Time 82.857049 s
# Loss (train) 0.412368	Regularization loss (train): 0.039443
# Reconstruction loss (train) 0.017942	 Prior loss (train) 0.962795
# Loss (test) 0.787475	Regularization loss (test): 0.078265
# Reconstruction loss (test) 0.004828	 Prior loss (test) 0.908335
# Epoch: 15
#
# Finished after 0.768620491027832s
# 33 cluster centers detected
#
# Iteration 8500:	Time 88.532753 s
# Loss (train) 0.326889	Regularization loss (train): 0.031229
# Reconstruction loss (train) 0.014604	 Prior loss (train) 0.967243
# Loss (test) 0.439988	Regularization loss (test): 0.042797
# Reconstruction loss (test) 0.012021	 Prior loss (test) 1.135299
# Epoch: 16
#
# Finished after 0.5512003898620605s
# 34 cluster centers detected
#
# Iteration 9000:	Time 93.517679 s
# Loss (train) 0.484766	Regularization loss (train): 0.047899
# Reconstruction loss (train) 0.005779	 Prior loss (train) 1.006117
# Loss (test) 0.840930	Regularization loss (test): 0.083491
# Reconstruction loss (test) 0.006020	 Prior loss (test) 1.081216
# Epoch: 17
#
# Finished after 0.716306209564209s
# 32 cluster centers detected
#
# Iteration 9500:	Time 99.228114 s
# Loss (train) 0.537575	Regularization loss (train): 0.052818
# Reconstruction loss (train) 0.009399	 Prior loss (train) 1.053280
# Loss (test) 0.457003	Regularization loss (test): 0.045350
# Reconstruction loss (test) 0.003503	 Prior loss (test) 0.983074
# Epoch: 18
#
# Finished after 0.5159976482391357s
# 31 cluster centers detected
#
# Iteration 10000:	Time 104.944772 s
# Loss (train) 0.483672	Regularization loss (train): 0.047304
# Reconstruction loss (train) 0.010630	 Prior loss (train) 0.862401
# Loss (test) 0.541550	Regularization loss (test): 0.053573
# Reconstruction loss (test) 0.005816	 Prior loss (test) 1.048407
# Epoch: 19
#
# Finished after 0.5382933616638184s
# 33 cluster centers detected
#
# Iteration 10500:	Time 110.858265 s
# Loss (train) 0.549982	Regularization loss (train): 0.054713
# Reconstruction loss (train) 0.002855	 Prior loss (train) 0.895414
# Loss (test) 0.450838	Regularization loss (test): 0.041594
# Reconstruction loss (test) 0.034898	 Prior loss (test) 0.835062
# Epoch: 20
#
# Finished after 0.5459284782409668s
# 31 cluster centers detected
#
# Iteration 11000:	Time 115.764813 s
# Loss (train) 0.764956	Regularization loss (train): 0.072461
# Reconstruction loss (train) 0.040347	 Prior loss (train) 0.904044
# Loss (test) 1.287914	Regularization loss (test): 0.128050
# Reconstruction loss (test) 0.007415	 Prior loss (test) 0.950615
# Epoch: 21
#
# Finished after 0.5372617244720459s
# 33 cluster centers detected
#
# Iteration 11500:	Time 120.911200 s
# Loss (train) 0.800453	Regularization loss (train): 0.079049
# Reconstruction loss (train) 0.009964	 Prior loss (train) 0.986258
# Loss (test) 0.499530	Regularization loss (test): 0.049294
# Reconstruction loss (test) 0.006588	 Prior loss (test) 1.052162
# Epoch: 22
#
# Finished after 0.516404390335083s
# 31 cluster centers detected
#
# Iteration 12000:	Time 126.389409 s
# Loss (train) 0.312552	Regularization loss (train): 0.030906
# Reconstruction loss (train) 0.003489	 Prior loss (train) 0.979596
# Loss (test) 0.849390	Regularization loss (test): 0.083017
# Reconstruction loss (test) 0.019221	 Prior loss (test) 0.868809
# Epoch: 23
#
# Finished after 0.5289373397827148s
# 31 cluster centers detected
#
# Iteration 12500:	Time 131.477972 s
# Loss (train) 0.228374	Regularization loss (train): 0.022394
# Reconstruction loss (train) 0.004437	 Prior loss (train) 0.972327
# Loss (test) 0.606964	Regularization loss (test): 0.060435
# Reconstruction loss (test) 0.002617	 Prior loss (test) 0.999081
# Epoch: 24
#
# Finished after 0.525700569152832s
# 32 cluster centers detected
#
# Iteration 13000:	Time 137.197684 s
# Loss (train) 0.344395	Regularization loss (train): 0.033151
# Reconstruction loss (train) 0.012882	 Prior loss (train) 1.097332
# Loss (test) 0.561858	Regularization loss (test): 0.054506
# Reconstruction loss (test) 0.016796	 Prior loss (test) 0.943388
# Epoch: 25
#
# Finished after 0.5308270454406738s
# 33 cluster centers detected
#
# Iteration 13500:	Time 142.133960 s
# Loss (train) 0.407865	Regularization loss (train): 0.040439
# Reconstruction loss (train) 0.003474	 Prior loss (train) 0.846252
# Loss (test) 0.668447	Regularization loss (test): 0.063657
# Reconstruction loss (test) 0.031880	 Prior loss (test) 0.880684
# Epoch: 26
#
# Finished after 0.8239920139312744s
# 30 cluster centers detected
#
# Iteration 14000:	Time 147.962835 s
# Loss (train) 0.843961	Regularization loss (train): 0.083828
# Reconstruction loss (train) 0.005677	 Prior loss (train) 1.019150
# Loss (test) 0.674257	Regularization loss (test): 0.067243
# Reconstruction loss (test) 0.001826	 Prior loss (test) 0.999440
# Epoch: 27
#
# Finished after 0.5641145706176758s
# 33 cluster centers detected
#
# Iteration 14500:	Time 152.981778 s
# Loss (train) 0.311970	Regularization loss (train): 0.031034
# Reconstruction loss (train) 0.001632	 Prior loss (train) 0.861131
# Loss (test) 0.558376	Regularization loss (test): 0.054900
# Reconstruction loss (test) 0.009372	 Prior loss (test) 0.930804
# Epoch: 28
#
# Finished after 1.9661967754364014s
# 30 cluster centers detected
#
# Iteration 15000:	Time 159.883913 s
# Loss (train) 0.507542	Regularization loss (train): 0.050122
# Reconstruction loss (train) 0.006318	 Prior loss (train) 0.992715
# Loss (test) 0.674755	Regularization loss (test): 0.065942
# Reconstruction loss (test) 0.015331	 Prior loss (test) 0.858854
# Iteration 15500:	Time 164.516306 s
# Loss (train) 0.369666	Regularization loss (train): 0.036682
# Reconstruction loss (train) 0.002845	 Prior loss (train) 1.103475
# Loss (test) 0.657143	Regularization loss (test): 0.056267
# Reconstruction loss (test) 0.094470	 Prior loss (test) 0.888995
# Epoch: 29
#
# Finished after 0.5124163627624512s
# 28 cluster centers detected
#
# Iteration 16000:	Time 169.512771 s
# Loss (train) 0.436089	Regularization loss (train): 0.043053
# Reconstruction loss (train) 0.005554	 Prior loss (train) 0.995431
# Loss (test) 0.999730	Regularization loss (test): 0.095407
# Reconstruction loss (test) 0.045664	 Prior loss (test) 0.929272
# Epoch: 30
#
# Finished after 0.5555906295776367s
# 33 cluster centers detected
#
# Iteration 16500:	Time 175.381507 s
# Loss (train) 0.561093	Regularization loss (train): 0.054729
# Reconstruction loss (train) 0.013806	 Prior loss (train) 0.950187
# Loss (test) 0.401541	Regularization loss (test): 0.040063
# Reconstruction loss (test) 0.000912	 Prior loss (test) 0.915300
# Epoch: 31
#
# Finished after 0.533374547958374s
# 32 cluster centers detected
#
# Iteration 17000:	Time 180.317638 s
# Loss (train) 1.534857	Regularization loss (train): 0.151114
# Reconstruction loss (train) 0.023717	 Prior loss (train) 1.116576
# Loss (test) 0.299510	Regularization loss (test): 0.026964
# Reconstruction loss (test) 0.029871	 Prior loss (test) 0.982479
# Epoch: 32
#
# Finished after 0.5112221240997314s
# 30 cluster centers detected
#
# Iteration 17500:	Time 186.084425 s
# Loss (train) 0.556618	Regularization loss (train): 0.055419
# Reconstruction loss (train) 0.002433	 Prior loss (train) 1.055745
# Loss (test) 0.462929	Regularization loss (test): 0.046000
# Reconstruction loss (test) 0.002930	 Prior loss (test) 0.916632
# Epoch: 33
#
# Finished after 0.5652179718017578s
# 32 cluster centers detected
#
# Iteration 18000:	Time 191.062360 s
# Loss (train) 0.287452	Regularization loss (train): 0.027060
# Reconstruction loss (train) 0.016851	 Prior loss (train) 0.941431
# Loss (test) 0.609985	Regularization loss (test): 0.059961
# Reconstruction loss (test) 0.010379	 Prior loss (test) 1.068715
# Epoch: 34
#
# Finished after 0.5269253253936768s
# 31 cluster centers detected
#
# Iteration 18500:	Time 196.313077 s
# Loss (train) 0.333156	Regularization loss (train): 0.031706
# Reconstruction loss (train) 0.016092	 Prior loss (train) 1.029825
# Loss (test) 1.074664	Regularization loss (test): 0.100976
# Reconstruction loss (test) 0.064904	 Prior loss (test) 1.087407
# Epoch: 35
#
# Finished after 0.49619483947753906s
# 29 cluster centers detected
#
# Iteration 19000:	Time 201.875908 s
# Loss (train) 0.729173	Regularization loss (train): 0.071887
# Reconstruction loss (train) 0.010302	 Prior loss (train) 0.960977
# Loss (test) 0.499101	Regularization loss (test): 0.046847
# Reconstruction loss (test) 0.030634	 Prior loss (test) 1.150484
# Epoch: 36
#
# Finished after 0.960423469543457s
# 33 cluster centers detected
#
# Iteration 19500:	Time 211.703808 s
# Loss (train) 0.723153	Regularization loss (train): 0.071833
# Reconstruction loss (train) 0.004818	 Prior loss (train) 0.787922
# Loss (test) 3.181695	Regularization loss (test): 0.317044
# Reconstruction loss (test) 0.011256	 Prior loss (test) 0.931473
# Epoch: 37
#
# Finished after 0.7191555500030518s
# 31 cluster centers detected
#
# Iteration 20000:	Time 217.802381 s
# Loss (train) 1.166982	Regularization loss (train): 0.116427
# Reconstruction loss (train) 0.002709	 Prior loss (train) 1.178586
# Loss (test) 1.162724	Regularization loss (test): 0.115348
# Reconstruction loss (test) 0.009246	 Prior loss (test) 1.230192
# Epoch: 38
#
# Finished after 0.5792827606201172s
# 33 cluster centers detected
#
# Iteration 20500:	Time 224.992201 s
# Loss (train) 0.442514	Regularization loss (train): 0.043833
# Reconstruction loss (train) 0.004187	 Prior loss (train) 0.970189
# Loss (test) 0.340785	Regularization loss (test): 0.033324
# Reconstruction loss (test) 0.007548	 Prior loss (test) 0.993774
# Epoch: 39
#
# Finished after 0.5802924633026123s
# 31 cluster centers detected
#
# Iteration 21000:	Time 232.336858 s
# Loss (train) 0.523605	Regularization loss (train): 0.050393
# Reconstruction loss (train) 0.019679	 Prior loss (train) 0.953757
# Loss (test) 0.955495	Regularization loss (test): 0.091665
# Reconstruction loss (test) 0.038846	 Prior loss (test) 0.981461
# Epoch: 40
#
# Finished after 0.5008907318115234s
# 27 cluster centers detected
#
# Iteration 21500:	Time 238.552885 s
# Loss (train) 0.642463	Regularization loss (train): 0.063489
# Reconstruction loss (train) 0.007575	 Prior loss (train) 0.977791
# Loss (test) 0.444315	Regularization loss (test): 0.041123
# Reconstruction loss (test) 0.033082	 Prior loss (test) 0.966338
# Epoch: 41
#
# Finished after 0.5156762599945068s
# 28 cluster centers detected
#
# Iteration 22000:	Time 243.638442 s
# Loss (train) 0.786021	Regularization loss (train): 0.078394
# Reconstruction loss (train) 0.002077	 Prior loss (train) 0.802188
# Loss (test) 0.887362	Regularization loss (test): 0.088505
# Reconstruction loss (test) 0.002310	 Prior loss (test) 0.967632
# Epoch: 42
#
# Finished after 1.5182216167449951s
# 30 cluster centers detected
#
# Iteration 22500:	Time 250.794374 s
# Loss (train) 0.597915	Regularization loss (train): 0.056802
# Reconstruction loss (train) 0.029898	 Prior loss (train) 1.057489
# Loss (test) 0.394970	Regularization loss (test): 0.036302
# Reconstruction loss (test) 0.031946	 Prior loss (test) 1.021921
# Epoch: 43
#
# Finished after 0.546375036239624s
# 30 cluster centers detected
#
# Iteration 23000:	Time 256.565507 s
# Loss (train) 0.943365	Regularization loss (train): 0.092999
# Reconstruction loss (train) 0.013370	 Prior loss (train) 0.992831
# Loss (test) 0.327222	Regularization loss (test): 0.032113
# Reconstruction loss (test) 0.006092	 Prior loss (test) 1.098000
# Epoch: 44
#
# Finished after 0.5329887866973877s
# 29 cluster centers detected
#
# Iteration 23500:	Time 262.495260 s
# Loss (train) 0.416548	Regularization loss (train): 0.041200
# Reconstruction loss (train) 0.004553	 Prior loss (train) 0.946839
# Loss (test) 0.294574	Regularization loss (test): 0.029244
# Reconstruction loss (test) 0.002134	 Prior loss (test) 0.914712
# Epoch: 45
#
# Finished after 0.6210799217224121s
# 29 cluster centers detected
#
# Iteration 24000:	Time 268.957493 s
# Loss (train) 0.406602	Regularization loss (train): 0.040536
# Reconstruction loss (train) 0.001242	 Prior loss (train) 0.964990
# Loss (test) 0.790836	Regularization loss (test): 0.078647
# Reconstruction loss (test) 0.004363	 Prior loss (test) 0.947722
# Iteration 24500:	Time 276.091604 s
# Loss (train) 0.561192	Regularization loss (train): 0.056012
# Reconstruction loss (train) 0.001074	 Prior loss (train) 0.907420
# Loss (test) 0.581901	Regularization loss (test): 0.057714
# Reconstruction loss (test) 0.004762	 Prior loss (test) 0.985349
# Epoch: 46
#
# Finished after 0.9806795120239258s
# 33 cluster centers detected
#
# Iteration 25000:	Time 284.012001 s
# Loss (train) 0.361244	Regularization loss (train): 0.035577
# Reconstruction loss (train) 0.005478	 Prior loss (train) 0.912958
# Loss (test) 0.457629	Regularization loss (test): 0.043024
# Reconstruction loss (test) 0.027391	 Prior loss (test) 0.941308
# Epoch: 47
#
# Finished after 0.8012709617614746s
# 28 cluster centers detected
#
# Iteration 25500:	Time 291.235614 s
# Loss (train) 0.296172	Regularization loss (train): 0.029393
# Reconstruction loss (train) 0.002240	 Prior loss (train) 1.028834
# Loss (test) 0.416400	Regularization loss (test): 0.041481
# Reconstruction loss (test) 0.001591	 Prior loss (test) 1.033670
# Epoch: 48
#
# Finished after 0.5384693145751953s
# 30 cluster centers detected
#
# Iteration 26000:	Time 296.798218 s
# Loss (train) 1.096558	Regularization loss (train): 0.106872
# Reconstruction loss (train) 0.027833	 Prior loss (train) 0.916913
# Loss (test) 0.473673	Regularization loss (test): 0.042597
# Reconstruction loss (test) 0.047705	 Prior loss (test) 0.946001
# Epoch: 49
#
# Finished after 0.8237273693084717s
# 31 cluster centers detected
#
# Iteration 26500:	Time 304.214492 s
# Loss (train) 0.702527	Regularization loss (train): 0.069808
# Reconstruction loss (train) 0.004442	 Prior loss (train) 0.867745
# Loss (test) 0.607582	Regularization loss (test): 0.060444
# Reconstruction loss (test) 0.003139	 Prior loss (test) 0.954631
# Epoch: 50
#
# Total training time: 305.727367
# Finished after 0.7130529880523682s
# 32 cluster centers detected
#
# Final: 0
# Loss (train) 0.658251	Regularization loss (train): 0.063813
# Reconstruction loss (train) 0.020121	 Prior loss (train) 1.016178
# Loss (test) 0.667327	Regularization loss (train): 0.064725
# Reconstruction loss (test) 0.020076	 Prior loss (test) 1.016822
# Beta: 10.000000	 Learning_rate: 0.001000

# %% [markdown]
# ## Result Analysis

# %%
prefix='Results/DynAE_d=2_dmin=5.0_b=10.000000_lr=0.001000'
repeat='0'

# %%
# load the results
# the latent representation recovered by Dynamics-AE
latent_rep=np.load(prefix+"_traj0_representation"+repeat+".npy")
# the reconstruction leanred by Dynamics-AE
reconstruction=np.load(prefix+"_traj0_data_prediction"+repeat+".npy")
# the cluster centers from regular space clustering in the latent space
cluster_centers=np.load(prefix+'_z_cluster_centers'+repeat+".npy")

# %%
# visualize the learned latent space
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig,ax = plt.subplots(figsize=(8,7))

RC_counts,RC_xbins,RC_ybins,images = plt.hist2d(latent_rep[:,0],latent_rep[:,1],bins=100)
RC_counts[RC_counts==0]=RC_counts[RC_counts!=0].min()
RC_G=-np.log(RC_counts)
RC_G=RC_G-np.nanmin(RC_G)

h0=plt.contourf(RC_G.transpose(),levels=10,extent=[RC_xbins[0],RC_xbins[-1],RC_ybins[0],RC_ybins[-1]],cmap='jet')
divider = make_axes_locatable(ax)
cax = divider.append_axes("top", "5%", pad="3%")
tickz = np.arange(0,RC_G.max(),5)
cb1 = fig.colorbar(h0, cax=cax, orientation="horizontal",ticks=tickz)
cb1.set_label(r'Free Energy ($k_BT$)',fontsize=40)
cax.xaxis.set_ticks_position("top")
cax.xaxis.set_label_position("top")
ax.set_xlabel(r"z$_0$")
ax.set_ylabel(r"z$_1$")
ax.axis('equal')
# Out:
# (-23.708566665649414,
#  14.591996192932129,
#  -13.047810554504395,
#  27.817502975463867)

# %%
# visualize the reconstruction
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig,ax = plt.subplots(figsize=(8,7))

RC_counts,RC_xbins,RC_ybins,images = plt.hist2d(reconstruction[:,0],reconstruction[:,1],bins=100)
RC_counts[RC_counts==0]=RC_counts[RC_counts!=0].min()
RC_G=-np.log(RC_counts)
RC_G=RC_G-np.nanmin(RC_G)

h0=plt.contourf(RC_G.transpose(),levels=10,extent=[RC_xbins[0],RC_xbins[-1],RC_ybins[0],RC_ybins[-1]],cmap='jet')
divider = make_axes_locatable(ax)
cax = divider.append_axes("top", "5%", pad="3%")
tickz = np.arange(0,RC_G.max(),5)
cb1 = fig.colorbar(h0, cax=cax, orientation="horizontal",ticks=tickz)
cb1.set_label(r'Free Energy ($k_BT$)',fontsize=48)
cax.xaxis.set_ticks_position("top")
cax.xaxis.set_label_position("top")
ax.set_xlabel(r"$\hat{x}$'")
ax.set_ylabel(r"$\hat{y}$'")
# Out:
# Text(0, 0.5, "$\\hat{y}$'")

# %%
# load the finally saved DynamicsAE model
import torch
from models.DynamicsAE import DynamicsAE

z_dim=2
output_shape=(2,)
data_shape=(2,)

neuron_num1=32
neuron_num2=32

projection_num=50
min_dist = 5
bias_factor = 2

# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu")

restore_path=prefix+'cpt0/DynAE_final_cpt.pt'

encoder_type = 'fc_encoder'

decoder_type = 'fc_decoder'

prior_dynamics = 'Langevin'

AE_model = DynamicsAE(encoder_type, decoder_type, prior_dynamics, z_dim, output_shape,
                      data_shape, projection_num, min_dist, bias_factor, device, neuron_num1, neuron_num2)

checkpoint=torch.load(restore_path)

AE_model.load_state_dict(checkpoint['state_dict'])
# Out:
# <All keys matched successfully>

# %%
def plot_ellipse(diff, x, ax, plot_scale=1, color='k'):
    """Plots the ellipse corresponding to a given covariance matrix at x (2D)
    Args:
        cov (array): 2 by 2 symmetric positive definite array.
        x (vector): 2 by 1 vector.
        scale (float, optional): Scale for ellipse size. Defaults to 1.
    """
    t = np.linspace(0, 2*np.pi)
    a = np.vstack([plot_scale*diff[0]*np.cos(t), plot_scale*diff[1]*np.sin(t)])
    ax.plot(a[0, :] + x[0], a[1, :] + x[1], linewidth=1, c=color)

# %%
# plot the diffusion learned DynamicsAE
n_pts = 10
batch_size = 256
margin = (latent_rep.max(axis=0)-latent_rep.min(axis=0))/n_pts
x = torch.linspace(latent_rep.min(axis=0)[0]+margin[0], latent_rep.max(axis=0)[0]-margin[0], n_pts)
y = torch.linspace(latent_rep.min(axis=0)[1]+margin[1], latent_rep.max(axis=0)[1]-margin[1], n_pts)
xx, yy = torch.meshgrid((x, y))
zz = torch.stack((xx.flatten(), yy.flatten()), dim=1)
xx = xx.flatten().cpu().detach().numpy()
yy = yy.flatten().cpu().detach().numpy()
diff = AE_model.model_prior.prior_logdiff(zz).exp()

diff = diff.cpu().detach().numpy()
zz = zz.cpu().detach().numpy()
# plot
fig, ax = plt.subplots(figsize=(9,7))

# visualize the learned latent space
from mpl_toolkits.axes_grid1 import make_axes_locatable

RC_counts,RC_xbins,RC_ybins,images = plt.hist2d(latent_rep[:,0],latent_rep[:,1],bins=100)
RC_counts[RC_counts==0]=RC_counts[RC_counts!=0].min()
RC_G=-np.log(RC_counts)
RC_G=RC_G-np.nanmin(RC_G)

h0=plt.contourf(RC_G.transpose(),levels=10,extent=[RC_xbins[0],RC_xbins[-1],RC_ybins[0],RC_ybins[-1]],cmap='jet')
divider = make_axes_locatable(ax)
cax = divider.append_axes("top", "5%", pad="3%")
tickz = np.arange(0,RC_G.max(),5)
cb1 = fig.colorbar(h0, cax=cax, orientation="horizontal",ticks=tickz)
cb1.set_label(r'Free Energy ($k_BT$)',fontsize=40)
cax.xaxis.set_ticks_position("top")
cax.xaxis.set_label_position("top")
ax.set_xlabel(r"z$_0$")
ax.set_ylabel(r"z$_1$")
ax.axis('equal')

for i in range(len(xx)):
    plot_ellipse(diff[i], zz[i], ax, plot_scale=1.5)

# %%
# plot the force field learned DynamicsAE
n_pts = 10
batch_size = 256

margin = (latent_rep.max(axis=0)-latent_rep.min(axis=0))/n_pts
x = torch.linspace(latent_rep.min(axis=0)[0]+margin[0], latent_rep.max(axis=0)[0]-margin[0], n_pts)
y = torch.linspace(latent_rep.min(axis=0)[1]+margin[1], latent_rep.max(axis=0)[1]-margin[1], n_pts)
xx, yy = torch.meshgrid((x, y))
zz = torch.stack((xx.flatten(), yy.flatten()), dim=1)
zz.requires_grad = True

force = AE_model.model_prior.prior_force(zz)

force = force.cpu().detach().numpy()
force[:,0]=force[:,0]
force[:,1]=force[:,1]
zz = zz.cpu().detach().numpy()
# plot
fig, ax = plt.subplots(figsize=(9,7))

# visualize the learned latent space
from mpl_toolkits.axes_grid1 import make_axes_locatable

RC_counts,RC_xbins,RC_ybins,images = plt.hist2d(latent_rep[:,0],latent_rep[:,1],bins=100)
RC_counts[RC_counts==0]=RC_counts[RC_counts!=0].min()
RC_G=-np.log(RC_counts)
RC_G=RC_G-np.nanmin(RC_G)

h0=plt.contourf(RC_G.transpose(),levels=10,extent=[RC_xbins[0],RC_xbins[-1],RC_ybins[0],RC_ybins[-1]],cmap='jet')
divider = make_axes_locatable(ax)
cax = divider.append_axes("top", "5%", pad="3%")
tickz = np.arange(0,RC_G.max(),5)
cb1 = fig.colorbar(h0, cax=cax, orientation="horizontal",ticks=tickz)
cb1.set_label(r'Free Energy ($k_BT$)',fontsize=40)
cax.xaxis.set_ticks_position("top")
cax.xaxis.set_label_position("top")
ax.set_xlabel(r"z$_0$")
ax.set_ylabel(r"z$_1$")
ax.set_xlim()
ax.axis('equal')

#ax.quiver(xx,yy,force[:,0],force[:,1]/yy.std)
ax.quiver(xx,yy,force[:,0],force[:,1])

# %% [markdown]
# ## 2. Run Dynamics-AE Model in a custom way

# %%
# import the required packages
import numpy as np
import torch
import os
import sys
import random
import torch.nn.functional as F

from models.VAE import VAE
from models.DynamicsAE import DynamicsAE
import utils

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
default_device = torch.device("cpu")
print(device, default_device)
# Out:
# cpu cpu

# %%
# Settings
# ------------------------------------------------------------------------------
# By default, we save all the results in subdirectories of the following path.
base_path = "Custom_Results"

# Model parameters

# By default, we use all the all the data to train and test our model
t0 = 0
# By default, set dt = 0 like normal auto-encoder
dt = 0

# Dimension of RC or bottleneck
z_dim = 2

# Encoder type (fc_encoder or conv_encoder)
encoder_type = 'fc_encoder'

# Decoder type (fc_decoder or deconv_decoder)
decoder_type = 'fc_decoder'

# Number of nodes in each hidden layer of the encoder
neuron_num1 = 32
# Number of nodes in each hidden layer of the encoder
neuron_num2 = 32

# Model (VAE or DynamicsAE)
model_type = 'DynamicsAE'
model_path = os.path.join(base_path, "DynAE")

# if model_type == 'DynamicsAE':
# Number of projections to approximate sliced wasserstein distance
projection_num = 50

# Minimal distances between cluster centers
min_dist = 5

# Bias factor for resampling
bias_factor = 2

# Prior dynamics (only support Langevin for now)
prior_dynamics = 'Langevin'

# Training parameters
batch_size = 256

# Number of epochs with the change of the state population smaller than the threshold after which this iteration of training finishes
max_epochs = 50

# By default, we save the model every 1 epoch
log_interval = 10

# Period of learning rate decay
lr_scheduler_step_size = 100

# Multiplicative factor of learning rate decay. Default: 1 (No learning rate decay)
lr_scheduler_gamma = 1

# learning rate of Adam optimizer for IB
learning_rate = 1e-3

# Hyper-parameter beta
beta = 10

# Import data

# Load the data
# Path to the input trajectory data
input_data_list = [np.load('examples/three_state_transformed_traj_data200k.npy')]

input_data_list = [torch.from_numpy(input_data).float().to(default_device)\
                  for input_data in input_data_list]

# Path to the target data
target_data_list = [torch.from_numpy(np.load('examples/three_state_transformed_traj_data200k.npy')).float().to(default_device)]

assert len(input_data_list)==len(target_data_list)

# Other controls

# Random seed
seed = 1

# Whether to save trajectory results
SaveTrajResults = True

# Whether to save training progress
SaveTrainingProgress = False

# %%
# Train and Test our model
# ------------------------------------------------------------------------------

final_result_path = model_path + '_result.dat'
os.makedirs(os.path.dirname(final_result_path), exist_ok=True)
if os.path.exists(final_result_path):
    print("Final Result", file=open(final_result_path, 'a'))  # append if already exists
else:
    print("Final Result", file=open(final_result_path, 'w'))

# set the random seed
np.random.seed(seed)
torch.manual_seed(seed)
random.seed(seed)

data_init_list = []
for i in range(len(input_data_list)):
    data_init_list += [utils.data_init(t0, dt, input_data_list[i], target_data_list[i])]

data_shape = data_init_list[0][0]

train_past_data0 = torch.cat([data_init_list[i][1] for i in range(len(input_data_list))], dim=0)
train_past_data1 = torch.cat([data_init_list[i][2] for i in range(len(input_data_list))], dim=0)
train_target_data0 = torch.cat([data_init_list[i][3] for i in range(len(input_data_list))], dim=0)
train_target_data1 = torch.cat([data_init_list[i][4] for i in range(len(input_data_list))], dim=0)

test_past_data0 = torch.cat([data_init_list[i][5] for i in range(len(input_data_list))], dim=0)
test_past_data1 = torch.cat([data_init_list[i][6] for i in range(len(input_data_list))], dim=0)
test_target_data0 = torch.cat([data_init_list[i][7] for i in range(len(input_data_list))], dim=0)
test_target_data1 = torch.cat([data_init_list[i][8] for i in range(len(input_data_list))], dim=0)

output_shape = train_target_data0.shape[1:]

# if model_type == 'DynamicsAE':
prior_learning_rate = learning_rate
output_path = model_path + "_d=%d_dmin=%.1f_b=%f_lr=%f" \
              % (z_dim, min_dist, beta, learning_rate)

AE_model = DynamicsAE(encoder_type, decoder_type, prior_dynamics, z_dim, output_shape,
                      data_shape, projection_num, min_dist, bias_factor, device, neuron_num1, neuron_num2)

AE_model.to(device)

AE_model.train()

train_result = AE_model.train_model(beta, input_data_list, train_past_data0,
                                  train_past_data1, train_target_data0,
                                  train_target_data1,
                                  test_past_data0, test_past_data1, test_target_data0,
                                  test_target_data1,
                                  learning_rate, prior_learning_rate,
                                  lr_scheduler_step_size, lr_scheduler_gamma,
                                  batch_size, max_epochs,
                                  output_path, log_interval,
                                  SaveTrainingProgress, seed)

AE_model.eval()
AE_model.output_final_result(train_past_data0, train_past_data1, train_target_data0, train_target_data1,
                          test_past_data0, test_past_data1, test_target_data0, test_target_data1,
                          batch_size, output_path, final_result_path, beta,
                          learning_rate, seed)

for i in range(len(input_data_list)):
    AE_model.save_traj_results(input_data_list[i], batch_size, output_path, SaveTrajResults, i, seed)
# Out:
# Iteration 500:	Time 5.942403 s
# Loss (train) 1.193887	Regularization loss (train): 2.971452
# Reconstruction loss (train) 0.896742	 Prior loss (train) -2.531919
# Loss (test) 31.443993	Regularization loss (test): 3.047678
# Reconstruction loss (test) 0.967217	 Prior loss (test) -2.658450
# Epoch: 1
#
# Finished after 0.24348020553588867s
# 3 cluster centers detected
#
# Iteration 1000:	Time 10.538867 s
# Loss (train) 3.826691	Regularization loss (train): 0.379242
# Reconstruction loss (train) 0.034275	 Prior loss (train) 0.540006
# Loss (test) 1.086867	Regularization loss (test): 0.107205
# Reconstruction loss (test) 0.014817	 Prior loss (test) 0.722007
# Epoch: 2
#
# Finished after 0.636376142501831s
# 14 cluster centers detected
#
# Iteration 1500:	Time 17.168092 s
# Loss (train) 1.177453	Regularization loss (train): 0.108730
# Reconstruction loss (train) 0.090158	 Prior loss (train) 0.864984
# Loss (test) 1.784779	Regularization loss (test): 0.176041
# Reconstruction loss (test) 0.024368	 Prior loss (test) 0.753401
# Epoch: 3
#
# Finished after 0.43837928771972656s
# 22 cluster centers detected
#
# Iteration 2000:	Time 22.521472 s
# Loss (train) 1.014328	Regularization loss (train): 0.100208
# Reconstruction loss (train) 0.012249	 Prior loss (train) 1.064165
# Loss (test) 1.513773	Regularization loss (test): 0.148786
# Reconstruction loss (test) 0.025912	 Prior loss (test) 0.932343
# Epoch: 4
#
# Finished after 0.5069515705108643s
# 28 cluster centers detected
#
# Iteration 2500:	Time 28.127867 s
# Loss (train) 0.658609	Regularization loss (train): 0.060321
# Reconstruction loss (train) 0.055396	 Prior loss (train) 0.901334
# Loss (test) 3.141578	Regularization loss (test): 0.307560
# Reconstruction loss (test) 0.065980	 Prior loss (test) 0.923228
# Epoch: 5
#
# Finished after 0.5053837299346924s
# 27 cluster centers detected
#
# Iteration 3000:	Time 32.991336 s
# Loss (train) 0.907541	Regularization loss (train): 0.086278
# Reconstruction loss (train) 0.044756	 Prior loss (train) 0.895229
# Loss (test) 0.490144	Regularization loss (test): 0.046491
# Reconstruction loss (test) 0.025234	 Prior loss (test) 0.898913
# Epoch: 6
#
# Finished after 0.5309808254241943s
# 30 cluster centers detected
#
# Iteration 3500:	Time 37.885170 s
# Loss (train) 1.108990	Regularization loss (train): 0.109836
# Reconstruction loss (train) 0.010630	 Prior loss (train) 0.714132
# Loss (test) 1.172862	Regularization loss (test): 0.115853
# Reconstruction loss (test) 0.014332	 Prior loss (test) 0.945081
# Epoch: 7
#
# Finished after 0.5228672027587891s
# 30 cluster centers detected
#
# Iteration 4000:	Time 43.537634 s
# Loss (train) 0.267692	Regularization loss (train): 0.025682
# Reconstruction loss (train) 0.010870	 Prior loss (train) 0.996652
# Loss (test) 0.418793	Regularization loss (test): 0.040326
# Reconstruction loss (test) 0.015534	 Prior loss (test) 0.824200
# Epoch: 8
#
# Finished after 0.5521259307861328s
# 33 cluster centers detected
#
# Iteration 4500:	Time 48.513245 s
# Loss (train) 2.663123	Regularization loss (train): 0.259423
# Reconstruction loss (train) 0.068896	 Prior loss (train) 0.963453
# Loss (test) 1.992608	Regularization loss (test): 0.195058
# Reconstruction loss (test) 0.042026	 Prior loss (test) 0.946194
# Epoch: 9
#
# Finished after 1.0535192489624023s
# 33 cluster centers detected
#
# Iteration 5000:	Time 55.553255 s
# Loss (train) 1.975785	Regularization loss (train): 0.194964
# Reconstruction loss (train) 0.026145	 Prior loss (train) 0.934607
# Loss (test) 1.073734	Regularization loss (test): 0.103285
# Reconstruction loss (test) 0.040880	 Prior loss (test) 1.002648
# Epoch: 10
#
# Finished after 0.5200884342193604s
# 30 cluster centers detected
#
# Iteration 5500:	Time 60.468086 s
# Loss (train) 0.594015	Regularization loss (train): 0.054720
# Reconstruction loss (train) 0.046816	 Prior loss (train) 0.986015
# Loss (test) 0.579293	Regularization loss (test): 0.054281
# Reconstruction loss (test) 0.036486	 Prior loss (test) 0.893205
# Epoch: 11
#
# Finished after 0.5119478702545166s
# 31 cluster centers detected
#
# Iteration 6000:	Time 65.271914 s
# Loss (train) 0.599476	Regularization loss (train): 0.059729
# Reconstruction loss (train) 0.002190	 Prior loss (train) 0.970726
# Loss (test) 0.497494	Regularization loss (test): 0.044291
# Reconstruction loss (test) 0.054587	 Prior loss (test) 1.032070
# Epoch: 12
#
# Finished after 0.5136070251464844s
# 31 cluster centers detected
#
# Iteration 6500:	Time 70.977091 s
# Loss (train) 0.415191	Regularization loss (train): 0.041211
# Reconstruction loss (train) 0.003086	 Prior loss (train) 0.968815
# Loss (test) 0.255775	Regularization loss (test): 0.024406
# Reconstruction loss (test) 0.011718	 Prior loss (test) 0.892769
# Epoch: 13
#
# Finished after 0.5180556774139404s
# 31 cluster centers detected
#
# Iteration 7000:	Time 75.767356 s
# Loss (train) 0.235192	Regularization loss (train): 0.022733
# Reconstruction loss (train) 0.007861	 Prior loss (train) 0.946030
# Loss (test) 0.754454	Regularization loss (test): 0.074056
# Reconstruction loss (test) 0.013891	 Prior loss (test) 1.028354
# Iteration 7500:	Time 80.912928 s
# Loss (train) 0.865250	Regularization loss (train): 0.085780
# Reconstruction loss (train) 0.007446	 Prior loss (train) 0.992337
# Loss (test) 0.555941	Regularization loss (test): 0.055369
# Reconstruction loss (test) 0.002249	 Prior loss (test) 1.082781
# Epoch: 14
#
# Finished after 0.5256137847900391s
# 31 cluster centers detected
#
# Iteration 8000:	Time 85.727314 s
# Loss (train) 0.336108	Regularization loss (train): 0.033367
# Reconstruction loss (train) 0.002439	 Prior loss (train) 0.897292
# Loss (test) 0.297919	Regularization loss (test): 0.029419
# Reconstruction loss (test) 0.003729	 Prior loss (test) 1.052934
# Epoch: 15
#
# Finished after 0.7036528587341309s
# 29 cluster centers detected
#
# Iteration 8500:	Time 92.639055 s
# Loss (train) 0.895364	Regularization loss (train): 0.088897
# Reconstruction loss (train) 0.006397	 Prior loss (train) 0.951181
# Loss (test) 0.672812	Regularization loss (test): 0.066899
# Reconstruction loss (test) 0.003827	 Prior loss (test) 0.993026
# Epoch: 16
#
# Finished after 0.988107442855835s
# 31 cluster centers detected
#
# Iteration 9000:	Time 98.702760 s
# Loss (train) 1.590435	Regularization loss (train): 0.157979
# Reconstruction loss (train) 0.010643	 Prior loss (train) 1.014834
# Loss (test) 0.618368	Regularization loss (test): 0.061435
# Reconstruction loss (test) 0.004015	 Prior loss (test) 1.091850
# Epoch: 17
#
# Finished after 0.5594155788421631s
# 31 cluster centers detected
#
# Iteration 9500:	Time 105.346641 s
# Loss (train) 0.238497	Regularization loss (train): 0.022529
# Reconstruction loss (train) 0.013203	 Prior loss (train) 0.926609
# Loss (test) 0.521361	Regularization loss (test): 0.050692
# Reconstruction loss (test) 0.014437	 Prior loss (test) 0.932977
# Epoch: 18
#
# Finished after 1.4365596771240234s
# 29 cluster centers detected
#
# Iteration 10000:	Time 112.312235 s
# Loss (train) 0.690454	Regularization loss (train): 0.068551
# Reconstruction loss (train) 0.004947	 Prior loss (train) 0.984445
# Loss (test) 0.540654	Regularization loss (test): 0.053570
# Reconstruction loss (test) 0.004959	 Prior loss (test) 0.980406
# Epoch: 19
#
# Finished after 0.551222562789917s
# 32 cluster centers detected
#
# Iteration 10500:	Time 117.261848 s
# Loss (train) 0.856274	Regularization loss (train): 0.083630
# Reconstruction loss (train) 0.019977	 Prior loss (train) 0.772309
# Loss (test) 0.636097	Regularization loss (test): 0.063291
# Reconstruction loss (test) 0.003183	 Prior loss (test) 0.908502
# Epoch: 20
#
# Finished after 1.3369817733764648s
# 32 cluster centers detected
#
# Iteration 11000:	Time 124.969038 s
# Loss (train) 0.439721	Regularization loss (train): 0.032975
# Reconstruction loss (train) 0.109974	 Prior loss (train) 1.083125
# Loss (test) 1.052222	Regularization loss (test): 0.097303
# Reconstruction loss (test) 0.079189	 Prior loss (test) 1.017215
# Epoch: 21
#
# Finished after 0.5278422832489014s
# 32 cluster centers detected
#
# Iteration 11500:	Time 130.004233 s
# Loss (train) 0.953479	Regularization loss (train): 0.095046
# Reconstruction loss (train) 0.003017	 Prior loss (train) 1.010056
# Loss (test) 0.935921	Regularization loss (test): 0.092397
# Reconstruction loss (test) 0.011952	 Prior loss (test) 0.946592
# Epoch: 22
#
# Finished after 0.9125568866729736s
# 34 cluster centers detected
#
# Iteration 12000:	Time 138.423209 s
# Loss (train) 0.318456	Regularization loss (train): 0.031698
# Reconstruction loss (train) 0.001473	 Prior loss (train) 0.894237
# Loss (test) 1.712413	Regularization loss (test): 0.170819
# Reconstruction loss (test) 0.004220	 Prior loss (test) 0.987008
# Epoch: 23
#
# Finished after 0.5179598331451416s
# 31 cluster centers detected
#
# Iteration 12500:	Time 143.443856 s
# Loss (train) 1.167330	Regularization loss (train): 0.116501
# Reconstruction loss (train) 0.002324	 Prior loss (train) 0.982093
# Loss (test) 0.630747	Regularization loss (test): 0.062821
# Reconstruction loss (test) 0.002540	 Prior loss (test) 0.975898
# Epoch: 24
#
# Finished after 1.0154342651367188s
# 32 cluster centers detected
#
# Iteration 13000:	Time 150.285437 s
# Loss (train) 0.895792	Regularization loss (train): 0.087913
# Reconstruction loss (train) 0.016661	 Prior loss (train) 0.851282
# Loss (test) 2.413315	Regularization loss (test): 0.236781
# Reconstruction loss (test) 0.045503	 Prior loss (test) 1.254120
# Epoch: 25
#
# Finished after 0.48467493057250977s
# 29 cluster centers detected
#
# Iteration 13500:	Time 155.300773 s
# Loss (train) 0.484302	Regularization loss (train): 0.047995
# Reconstruction loss (train) 0.004352	 Prior loss (train) 0.902206
# Loss (test) 0.811431	Regularization loss (test): 0.076073
# Reconstruction loss (test) 0.050699	 Prior loss (test) 0.972748
# Epoch: 26
#
# Finished after 0.8492767810821533s
# 32 cluster centers detected
#
# Iteration 14000:	Time 161.127596 s
# Loss (train) 0.552856	Regularization loss (train): 0.055150
# Reconstruction loss (train) 0.001355	 Prior loss (train) 1.087756
# Loss (test) 0.366199	Regularization loss (test): 0.036468
# Reconstruction loss (test) 0.001516	 Prior loss (test) 0.882441
# Epoch: 27
#
# Finished after 0.5273394584655762s
# 30 cluster centers detected
#
# Iteration 14500:	Time 166.864201 s
# Loss (train) 0.491670	Regularization loss (train): 0.047560
# Reconstruction loss (train) 0.016066	 Prior loss (train) 0.988434
# Loss (test) 1.518957	Regularization loss (test): 0.151643
# Reconstruction loss (test) 0.002527	 Prior loss (test) 0.885395
# Epoch: 28
#
# Finished after 0.9144654273986816s
# 32 cluster centers detected
#
# Iteration 15000:	Time 173.277614 s
# Loss (train) 2.461516	Regularization loss (train): 0.245150
# Reconstruction loss (train) 0.010016	 Prior loss (train) 0.926875
# Loss (test) 1.215655	Regularization loss (test): 0.120830
# Reconstruction loss (test) 0.007350	 Prior loss (test) 0.948830
# Epoch: 29
#
# Finished after 0.5787456035614014s
# 37 cluster centers detected
#
# Iteration 15500:	Time 178.577394 s
# Loss (train) 0.614555	Regularization loss (train): 0.061071
# Reconstruction loss (train) 0.003840	 Prior loss (train) 0.918134
# Loss (test) 0.399323	Regularization loss (test): 0.038264
# Reconstruction loss (test) 0.016681	 Prior loss (test) 0.918568
# Epoch: 30
#
# Finished after 0.534121036529541s
# 33 cluster centers detected
#
# Iteration 16000:	Time 183.402386 s
# Loss (train) 0.347883	Regularization loss (train): 0.033958
# Reconstruction loss (train) 0.008306	 Prior loss (train) 0.940853
# Loss (test) 0.441855	Regularization loss (test): 0.043995
# Reconstruction loss (test) 0.001906	 Prior loss (test) 0.879736
# Epoch: 31
#
# Finished after 0.5410752296447754s
# 31 cluster centers detected
#
# Iteration 16500:	Time 189.127745 s
# Loss (train) 0.376083	Regularization loss (train): 0.036496
# Reconstruction loss (train) 0.011126	 Prior loss (train) 0.936777
# Loss (test) 1.176013	Regularization loss (test): 0.112148
# Reconstruction loss (test) 0.054530	 Prior loss (test) 0.917772
# Epoch: 32
#
# Finished after 0.5653502941131592s
# 32 cluster centers detected
#
# Iteration 17000:	Time 194.038816 s
# Loss (train) 0.564172	Regularization loss (train): 0.055962
# Reconstruction loss (train) 0.004553	 Prior loss (train) 1.006111
# Loss (test) 0.365158	Regularization loss (test): 0.035604
# Reconstruction loss (test) 0.009117	 Prior loss (test) 1.060829
# Iteration 17500:	Time 199.061315 s
# Loss (train) 0.905541	Regularization loss (train): 0.085909
# Reconstruction loss (train) 0.046451	 Prior loss (train) 0.966032
# Loss (test) 0.658924	Regularization loss (test): 0.065535
# Reconstruction loss (test) 0.003575	 Prior loss (test) 1.094852
# Epoch: 33
#
# Finished after 0.529984712600708s
# 30 cluster centers detected
#
# Iteration 18000:	Time 204.020613 s
# Loss (train) 0.434759	Regularization loss (train): 0.043110
# Reconstruction loss (train) 0.003661	 Prior loss (train) 0.941718
# Loss (test) 0.765326	Regularization loss (test): 0.074839
# Reconstruction loss (test) 0.016934	 Prior loss (test) 0.978832
# Epoch: 34
#
# Finished after 0.5494012832641602s
# 34 cluster centers detected
#
# Iteration 18500:	Time 208.993565 s
# Loss (train) 0.656783	Regularization loss (train): 0.065182
# Reconstruction loss (train) 0.004966	 Prior loss (train) 1.005203
# Loss (test) 0.548699	Regularization loss (test): 0.054579
# Reconstruction loss (test) 0.002904	 Prior loss (test) 0.914787
# Epoch: 35
#
# Finished after 0.8868002891540527s
# 33 cluster centers detected
#
# Iteration 19000:	Time 215.721473 s
# Loss (train) 0.607358	Regularization loss (train): 0.059660
# Reconstruction loss (train) 0.010760	 Prior loss (train) 1.064380
# Loss (test) 0.232135	Regularization loss (test): 0.022326
# Reconstruction loss (test) 0.008872	 Prior loss (test) 1.005323
# Epoch: 36
#
# Finished after 0.5260076522827148s
# 30 cluster centers detected
#
# Iteration 19500:	Time 220.486923 s
# Loss (train) 0.629037	Regularization loss (train): 0.062470
# Reconstruction loss (train) 0.004332	 Prior loss (train) 0.900626
# Loss (test) 0.635365	Regularization loss (test): 0.063334
# Reconstruction loss (test) 0.002024	 Prior loss (test) 1.049752
# Epoch: 37
#
# Finished after 0.49481701850891113s
# 29 cluster centers detected
#
# Iteration 20000:	Time 226.036116 s
# Loss (train) 0.650286	Regularization loss (train): 0.064723
# Reconstruction loss (train) 0.003052	 Prior loss (train) 0.981361
# Loss (test) 0.460268	Regularization loss (test): 0.045366
# Reconstruction loss (test) 0.006604	 Prior loss (test) 1.012072
# Epoch: 38
#
# Finished after 0.5199317932128906s
# 30 cluster centers detected
#
# Iteration 20500:	Time 231.004941 s
# Loss (train) 0.686020	Regularization loss (train): 0.067856
# Reconstruction loss (train) 0.007463	 Prior loss (train) 1.029429
# Loss (test) 0.416026	Regularization loss (test): 0.040627
# Reconstruction loss (test) 0.009756	 Prior loss (test) 0.907895
# Epoch: 39
#
# Finished after 0.5074272155761719s
# 30 cluster centers detected
#
# Iteration 21000:	Time 235.784555 s
# Loss (train) 1.530693	Regularization loss (train): 0.152467
# Reconstruction loss (train) 0.006022	 Prior loss (train) 1.099615
# Loss (test) 0.889190	Regularization loss (test): 0.088283
# Reconstruction loss (test) 0.006361	 Prior loss (test) 1.035934
# Epoch: 40
#
# Finished after 0.8466665744781494s
# 34 cluster centers detected
#
# Iteration 21500:	Time 241.518739 s
# Loss (train) 0.385140	Regularization loss (train): 0.037847
# Reconstruction loss (train) 0.006668	 Prior loss (train) 0.971748
# Loss (test) 0.641156	Regularization loss (test): 0.060695
# Reconstruction loss (test) 0.034211	 Prior loss (test) 0.986953
# Epoch: 41
#
# Finished after 0.5416898727416992s
# 33 cluster centers detected
#
# Iteration 22000:	Time 246.389626 s
# Loss (train) 0.669920	Regularization loss (train): 0.066593
# Reconstruction loss (train) 0.003993	 Prior loss (train) 1.021102
# Loss (test) 0.631855	Regularization loss (test): 0.062460
# Reconstruction loss (test) 0.007257	 Prior loss (test) 0.931758
# Epoch: 42
#
# Finished after 0.8963885307312012s
# 31 cluster centers detected
#
# Iteration 22500:	Time 252.817615 s
# Loss (train) 0.532406	Regularization loss (train): 0.052941
# Reconstruction loss (train) 0.002999	 Prior loss (train) 0.920466
# Loss (test) 0.863777	Regularization loss (test): 0.086109
# Reconstruction loss (test) 0.002687	 Prior loss (test) 0.912012
# Epoch: 43
#
# Finished after 0.5587470531463623s
# 31 cluster centers detected
#
# Iteration 23000:	Time 257.894364 s
# Loss (train) 1.074423	Regularization loss (train): 0.100980
# Reconstruction loss (train) 0.064623	 Prior loss (train) 0.751680
# Loss (test) 0.542874	Regularization loss (test): 0.054130
# Reconstruction loss (test) 0.001572	 Prior loss (test) 1.016717
# Epoch: 44
#
# Finished after 0.5054848194122314s
# 29 cluster centers detected
#
# Iteration 23500:	Time 262.673754 s
# Loss (train) 0.629276	Regularization loss (train): 0.060611
# Reconstruction loss (train) 0.023169	 Prior loss (train) 1.029211
# Loss (test) 0.486436	Regularization loss (test): 0.045750
# Reconstruction loss (test) 0.028935	 Prior loss (test) 0.965800
# Epoch: 45
#
# Finished after 0.5592539310455322s
# 32 cluster centers detected
#
# Iteration 24000:	Time 268.416094 s
# Loss (train) 0.795760	Regularization loss (train): 0.079201
# Reconstruction loss (train) 0.003746	 Prior loss (train) 1.000391
# Loss (test) 0.391769	Regularization loss (test): 0.038169
# Reconstruction loss (test) 0.010079	 Prior loss (test) 0.906952
# Epoch: 46
#
# Finished after 0.5676069259643555s
# 35 cluster centers detected
#
# Iteration 24500:	Time 273.335457 s
# Loss (train) 0.353370	Regularization loss (train): 0.034954
# Reconstruction loss (train) 0.003833	 Prior loss (train) 0.952775
# Loss (test) 0.486989	Regularization loss (test): 0.048506
# Reconstruction loss (test) 0.001931	 Prior loss (test) 0.924269
# Epoch: 47
#
# Finished after 0.7840945720672607s
# 29 cluster centers detected
#
# Iteration 25000:	Time 279.039902 s
# Loss (train) 0.364357	Regularization loss (train): 0.036390
# Reconstruction loss (train) 0.000456	 Prior loss (train) 0.961746
# Loss (test) 0.283192	Regularization loss (test): 0.027962
# Reconstruction loss (test) 0.003575	 Prior loss (test) 0.941401
# Epoch: 48
#
# Finished after 0.5375607013702393s
# 32 cluster centers detected
#
# Iteration 25500:	Time 283.933543 s
# Loss (train) 1.087037	Regularization loss (train): 0.104542
# Reconstruction loss (train) 0.041616	 Prior loss (train) 0.912223
# Loss (test) 0.334628	Regularization loss (test): 0.033253
# Reconstruction loss (test) 0.002100	 Prior loss (test) 0.962564
# Epoch: 49
#
# Finished after 0.843393087387085s
# 30 cluster centers detected
#
# Iteration 26000:	Time 289.893395 s
# Loss (train) 0.294746	Regularization loss (train): 0.027441
# Reconstruction loss (train) 0.020335	 Prior loss (train) 0.908759
# Loss (test) 0.855621	Regularization loss (test): 0.083317
# Reconstruction loss (test) 0.022447	 Prior loss (test) 0.892800
# Epoch: 50
#
# Total training time: 295.111215
# Finished after 0.5361919403076172s
# 34 cluster centers detected
#
# Final: 1
# Loss (train) 0.575382	Regularization loss (train): 0.056288
# Reconstruction loss (train) 0.012498	 Prior loss (train) 0.986758
# Loss (test) 0.576491	Regularization loss (train): 0.056539
# Reconstruction loss (test) 0.011104	 Prior loss (test) 0.980004
# Beta: 10.000000	 Learning_rate: 0.001000

# %% [markdown]
# ## Result Analysis

# %%
prefix='Custom_Results/DynAE_d=2_dmin=5.0_b=10.000000_lr=0.001000'
repeat='1'

# %%
# load the results
# the latent representation recovered by Dynamics-AE
latent_rep=np.load(prefix+"_traj0_representation"+repeat+".npy")
# the reconstruction leanred by Dynamics-AE
reconstruction=np.load(prefix+"_traj0_data_prediction"+repeat+".npy")
# the cluster centers from regular space clustering in the latent space
cluster_centers=np.load(prefix+'_z_cluster_centers'+repeat+".npy")

# %%
# visualize the learned latent space
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig,ax = plt.subplots(figsize=(8,7))

RC_counts,RC_xbins,RC_ybins,images = plt.hist2d(latent_rep[:,0],latent_rep[:,1],bins=100)
RC_counts[RC_counts==0]=RC_counts[RC_counts!=0].min()
RC_G=-np.log(RC_counts)
RC_G=RC_G-np.nanmin(RC_G)

h0=plt.contourf(RC_G.transpose(),levels=10,extent=[RC_xbins[0],RC_xbins[-1],RC_ybins[0],RC_ybins[-1]],cmap='jet')
divider = make_axes_locatable(ax)
cax = divider.append_axes("top", "5%", pad="3%")
tickz = np.arange(0,RC_G.max(),5)
cb1 = fig.colorbar(h0, cax=cax, orientation="horizontal",ticks=tickz)
cb1.set_label(r'Free Energy ($k_BT$)',fontsize=40)
cax.xaxis.set_ticks_position("top")
cax.xaxis.set_label_position("top")
ax.set_xlabel(r"z$_0$")
ax.set_ylabel(r"z$_1$")
ax.axis('equal')
# Out:
# (-17.557727813720703,
#  22.866613388061523,
#  -17.733871459960938,
#  23.003271102905273)

# %%
# visualize the reconstruction
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig,ax = plt.subplots(figsize=(8,7))

RC_counts,RC_xbins,RC_ybins,images = plt.hist2d(reconstruction[:,0],reconstruction[:,1],bins=100)
RC_counts[RC_counts==0]=RC_counts[RC_counts!=0].min()
RC_G=-np.log(RC_counts)
RC_G=RC_G-np.nanmin(RC_G)

h0=plt.contourf(RC_G.transpose(),levels=10,extent=[RC_xbins[0],RC_xbins[-1],RC_ybins[0],RC_ybins[-1]],cmap='jet')
divider = make_axes_locatable(ax)
cax = divider.append_axes("top", "5%", pad="3%")
tickz = np.arange(0,RC_G.max(),5)
cb1 = fig.colorbar(h0, cax=cax, orientation="horizontal",ticks=tickz)
cb1.set_label(r'Free Energy ($k_BT$)',fontsize=48)
cax.xaxis.set_ticks_position("top")
cax.xaxis.set_label_position("top")
ax.set_xlabel(r"$\hat{x}$'")
ax.set_ylabel(r"$\hat{y}$'")
# Out:
# Text(0, 0.5, "$\\hat{y}$'")

# %%
# load the finally saved DynamicsAE model
import torch
from models.DynamicsAE import DynamicsAE

z_dim=2
output_shape=(2,)
data_shape=(2,)

neuron_num1=32
neuron_num2=32

projection_num=50
min_dist = 5
bias_factor = 2

# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu")

restore_path=prefix+'cpt1/DynAE_final_cpt.pt'

encoder_type = 'fc_encoder'

decoder_type = 'fc_decoder'

prior_dynamics = 'Langevin'

AE_model = DynamicsAE(encoder_type, decoder_type, prior_dynamics, z_dim, output_shape,
                      data_shape, projection_num, min_dist, bias_factor, device, neuron_num1, neuron_num2)

checkpoint=torch.load(restore_path)

AE_model.load_state_dict(checkpoint['state_dict'])
# Out:
# <All keys matched successfully>

# %%
# plot the diffusion learned DynamicsAE
n_pts = 10
batch_size = 256
margin = (latent_rep.max(axis=0)-latent_rep.min(axis=0))/n_pts
x = torch.linspace(latent_rep.min(axis=0)[0]+margin[0], latent_rep.max(axis=0)[0]-margin[0], n_pts)
y = torch.linspace(latent_rep.min(axis=0)[1]+margin[1], latent_rep.max(axis=0)[1]-margin[1], n_pts)
xx, yy = torch.meshgrid((x, y))
zz = torch.stack((xx.flatten(), yy.flatten()), dim=1)
xx = xx.flatten().cpu().detach().numpy()
yy = yy.flatten().cpu().detach().numpy()
diff = AE_model.model_prior.prior_logdiff(zz).exp()

diff = diff.cpu().detach().numpy()
zz = zz.cpu().detach().numpy()
# plot
fig, ax = plt.subplots(figsize=(9,7))

# visualize the learned latent space
from mpl_toolkits.axes_grid1 import make_axes_locatable

RC_counts,RC_xbins,RC_ybins,images = plt.hist2d(latent_rep[:,0],latent_rep[:,1],bins=100)
RC_counts[RC_counts==0]=RC_counts[RC_counts!=0].min()
RC_G=-np.log(RC_counts)
RC_G=RC_G-np.nanmin(RC_G)

h0=plt.contourf(RC_G.transpose(),levels=10,extent=[RC_xbins[0],RC_xbins[-1],RC_ybins[0],RC_ybins[-1]],cmap='jet')
divider = make_axes_locatable(ax)
cax = divider.append_axes("top", "5%", pad="3%")
tickz = np.arange(0,RC_G.max(),5)
cb1 = fig.colorbar(h0, cax=cax, orientation="horizontal",ticks=tickz)
cb1.set_label(r'Free Energy ($k_BT$)',fontsize=40)
cax.xaxis.set_ticks_position("top")
cax.xaxis.set_label_position("top")
ax.set_xlabel(r"z$_0$")
ax.set_ylabel(r"z$_1$")
ax.axis('equal')

for i in range(len(xx)):
    plot_ellipse(diff[i], zz[i], ax, plot_scale=1.5)

# %%
# plot the force field learned DynamicsAE
n_pts = 10
batch_size = 256

margin = (latent_rep.max(axis=0)-latent_rep.min(axis=0))/n_pts
x = torch.linspace(latent_rep.min(axis=0)[0]+margin[0], latent_rep.max(axis=0)[0]-margin[0], n_pts)
y = torch.linspace(latent_rep.min(axis=0)[1]+margin[1], latent_rep.max(axis=0)[1]-margin[1], n_pts)
xx, yy = torch.meshgrid((x, y))
zz = torch.stack((xx.flatten(), yy.flatten()), dim=1)
zz.requires_grad = True

force = AE_model.model_prior.prior_force(zz)

force = force.cpu().detach().numpy()
force[:,0]=force[:,0]
force[:,1]=force[:,1]
zz = zz.cpu().detach().numpy()
# plot
fig, ax = plt.subplots(figsize=(9,7))

# visualize the learned latent space
from mpl_toolkits.axes_grid1 import make_axes_locatable

RC_counts,RC_xbins,RC_ybins,images = plt.hist2d(latent_rep[:,0],latent_rep[:,1],bins=100)
RC_counts[RC_counts==0]=RC_counts[RC_counts!=0].min()
RC_G=-np.log(RC_counts)
RC_G=RC_G-np.nanmin(RC_G)

h0=plt.contourf(RC_G.transpose(),levels=10,extent=[RC_xbins[0],RC_xbins[-1],RC_ybins[0],RC_ybins[-1]],cmap='jet')
divider = make_axes_locatable(ax)
cax = divider.append_axes("top", "5%", pad="3%")
tickz = np.arange(0,RC_G.max(),5)
cb1 = fig.colorbar(h0, cax=cax, orientation="horizontal",ticks=tickz)
cb1.set_label(r'Free Energy ($k_BT$)',fontsize=40)
cax.xaxis.set_ticks_position("top")
cax.xaxis.set_label_position("top")
ax.set_xlabel(r"z$_0$")
ax.set_ylabel(r"z$_1$")
ax.set_xlim()
ax.axis('equal')

#ax.quiver(xx,yy,force[:,0],force[:,1]/yy.std)
ax.quiver(xx,yy,force[:,0],force[:,1])
